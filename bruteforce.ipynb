# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
grid = cv2.imread('grids/grid.jpeg')

# %%
plt.imshow(grid)

# %%
red = cv2.imread('training_grid/red.png')

# %%
plt.imshow(red)

# %%
img = grid.astype('float32')

# %%
img
# Out:
# array([[[203., 224., 225.],
#         [205., 226., 227.],
#         [207., 226., 229.],
#         ...,
#         [180., 188., 187.],
#         [180., 188., 187.],
#         [180., 188., 187.]],
#
#        [[205., 226., 227.],
#         [203., 224., 225.],
#         [205., 224., 227.],
#         ...,
#         [181., 189., 188.],
#         [181., 189., 188.],
#         [181., 189., 188.]],
#
#        [[204., 225., 226.],
#         [202., 223., 224.],
#         [204., 223., 226.],
#         ...,
#         [181., 189., 188.],
#         [182., 190., 189.],
#         [182., 190., 189.]],
#
#        ...,
#
#        [[125., 127., 127.],
#         [128., 130., 130.],
#         [124., 126., 126.],
#         ...,
#         [152., 181., 185.],
#         [150., 179., 183.],
#         [149., 178., 182.]],
#
#        [[128., 131., 129.],
#         [129., 132., 130.],
#         [125., 128., 126.],
#         ...,
#         [147., 178., 179.],
#         [146., 177., 178.],
# ...

# %%
img.shape
# Out:
# (4032, 3024, 3)

# %%
new_red = red.astype('float32')

# %%
new_red.shape
# Out:
# (160, 162, 3)

# %%
new_matrices
